# %% [markdown]
# # Notebook 05: Multi-Dimensional Evidence Ranking
# Demonstrates how multi-dimensional evidence components (Relevance, Authority, Freshness, Approval, Citation, Revision, Conflict) combine into an interpretable score.

# %%
from src.search.evidence_ranker import EvidenceRanker
ranker = EvidenceRanker()
res = ranker.search("What database should we use for Project Alpha?", user_id="user_001")
print("Top Doc Score Breakdown:", res["top_document"]["scores"])

# %% [markdown]
# # Notebook 04: Baseline Search Evaluation
# Evaluates pure BM25 search baseline without evidence ranking.

# %%
from src.evaluation.evaluate_baseline import evaluate_baseline_search
metrics = evaluate_baseline_search()
print(metrics)

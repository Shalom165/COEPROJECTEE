# %% [markdown]
# # Notebook 06: Dense Semantic Search
# Inspects SentenceTransformers vector embeddings and cosine similarity retrieval.

# %%
import pandas as pd
from src.config.settings import settings
from src.search.semantic_search import SemanticSearchEngine

docs = pd.read_csv(settings.CLEANED_DATA_DIR / "documents_cleaned.csv")
engine = SemanticSearchEngine(docs)
res = engine.search("ACID compliant enterprise relational storage platform", top_k=5)
print(res)

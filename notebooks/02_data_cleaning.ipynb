# %% [markdown]
# # Notebook 02: Data Cleaning & Preprocessing
# Demonstrates text normalization, date standardization, deduplication, and quality report generation.

# %%
from src.data.clean_data import clean_documents
from src.data.validate_data import validate_datasets

report = clean_documents()
valid, errors = validate_datasets()
print("Validation Status:", valid)

# %% [markdown]
# # Notebook 01: Synthetic Data Generation
# This notebook demonstrates the synthetic generation of 1,000+ enterprise architecture documents across 22 technical domains.

# %%
import pandas as pd
from src.data.generate_dataset import generate_documents

docs, meta, revs, perms, cits, confs = generate_documents(count=1000)
print(f"Generated {len(docs)} documents and {len(perms)} permission records.")
docs.head()

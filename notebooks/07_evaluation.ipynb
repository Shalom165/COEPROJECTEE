# %% [markdown]
# # Notebook 07: Full Comparative Evaluation
# Compares Baseline Search vs Evidence-Ranked Search across Precision, Recall, MRR, NDCG, Latency, and Acceptance Rate.

# %%
from src.evaluation.evaluate_baseline import evaluate_baseline_search
from src.evaluation.evaluate_prototype import evaluate_prototype_search

base_metrics = evaluate_baseline_search()
proto_metrics = evaluate_prototype_search()

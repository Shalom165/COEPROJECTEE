# %% [markdown]
# # Notebook 03: Exploratory Data Analysis (EDA)
# Analyzes document distributions by department, approval status, authority level, and age.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.config.settings import settings

docs = pd.read_csv(settings.CLEANED_DATA_DIR / "documents_cleaned.csv")
docs["department"].value_counts().plot(kind="bar", title="Documents by Department")
plt.show()
